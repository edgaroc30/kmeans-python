# %% [markdown]
# # Clustering using Buildingsdataset

# %% [markdown]
# ### Loading libraries

# %%
from sklearn import cluster, datasets
from sklearn.cluster import KMeans
from sklearn import metrics
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import scale

# %% [markdown]
# ### Loading Buidings dataset

# %%
buildings = pd.read_csv('ICAEN.csv')

# %%
buildings.columns =['year','usage','global_emissions','loc',
                    'habit_area','compactness','demand',
                    'gas_demand','electricity_deman','diesel_demand','eco_demand','c02','energy_primary']

# %%
plt.title("Histograms Year")
plt.hist(buildings['year'], bins=50, alpha=0.3,range=[1700,2020])
plt.axvline(buildings['year'].mean(), color='b', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms Global Emissions")
plt.hist(buildings['global_emissions'], bins=50, alpha=0.3,range=[0,200])
plt.axvline(buildings['global_emissions'].mean(), color='b', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms Municiplality")
plt.hist(buildings['loc'], bins=50, alpha=0.3)
plt.show()

# %%
plt.title("Histograms Electricity Demand")
plt.hist(buildings['habit_area'], bins=50, alpha=0.3,range=[10,1000],color='b')
plt.axvline(buildings['habit_area'].mean(), color='b', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms Compactness")
plt.hist(buildings['compactness'], bins=50, alpha=0.3,range=[0,10],color='r')
plt.axvline(buildings['compactness'].mean(), color='r', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms Demand")
plt.hist(buildings['demand'], bins=50, alpha=0.3,color='g')
plt.axvline(buildings['demand'].mean(), color='g', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms Gas Demand")
plt.hist(buildings['gas_demand'], bins=50, alpha=0.3,color='y')
plt.axvline(buildings['gas_demand'].mean(), color='y', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms Electricity Demand")
plt.hist(buildings['electricity_deman'], bins=50, alpha=0.3,color='b',range=[0,10])
plt.axvline(buildings['electricity_deman'].mean(), color='b', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms Diesel Demand")
plt.hist(buildings['diesel_demand'], bins=50, alpha=0.3,color='b',range=[0,1])
plt.axvline(buildings['diesel_demand'].mean(), color='b', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms Eco Demand")
plt.hist(buildings['eco_demand'], bins=50, alpha=0.3,color='b',range=[0,1500])
plt.axvline(buildings['eco_demand'].mean(), color='b', linestyle='dashed', linewidth=3)
plt.show()

# %%
plt.title("Histograms C02")
plt.hist(buildings['c02'], bins=50, alpha=0.3,color='b')
plt.show()

# %%
plt.title("Histograms Energy Primary")
plt.hist(buildings['energy_primary'], bins=50, alpha=0.3,color='b')
plt.show()

# %% [markdown]
# From the previous graphs we can see that a couple of attributes will introduce a lot of noise to the sample so it won't be taken into consideration

# %%
buildings = buildings.drop(columns=['loc','usage'])

# %%
buildings.describe()
# Out:
#                year  global_emissions    habit_area   compactness  \
# count  33628.000000      33628.000000  33628.000000  33628.000000
# mean    1973.143720         49.419601    134.683265      1.547255
# std       36.089279         41.118207    107.804274      1.448973
# min     1400.000000          0.000000     16.950000      0.210000
# 25%     1961.000000         35.690000     83.000000      0.950000
# 50%     1982.000000         47.065000    117.105000      1.250000
# 75%     1999.000000         60.552500    160.345000      1.710000
# max     2088.000000       6584.320000  12282.000000    104.370000
#
#              demand    gas_demand  electricity_deman  diesel_demand  \
# count  33628.000000  33628.000000       33628.000000   33628.000000
# mean     157.498752    115.112469          24.247886       0.625729
# std       55.901711    107.786835         118.355423      13.109612
# min       11.880000      0.000000         -99.100000       0.000000
# 25%      117.637500      0.000000           0.000000       0.000000
# 50%      150.355000    115.190000           1.860000       0.000000
# 75%      190.510000    194.360000          26.030000       0.000000
# max      685.350000    973.940000       19879.990000     653.000000
#
#          eco_demand
# count  33628.000000
# mean     243.097760
# std      233.279383
# min        0.000000
# 25%      175.790000
# 50%      229.865000
# 75%      296.555000
# max    38865.210000

# %%
string_to_int = lambda x: ord(x)
buildings['energy_primary'] = buildings['energy_primary'].map(string_to_int)
buildings['c02']= buildings['c02'].map(string_to_int)

# %%
buildings = scale(buildings)

# %% [markdown]
# ### Defining the number of clusters to produce

# %%
def plot_results(inertials):
    x, y = zip(*[inertia for inertia in inertials])
    plt.plot(x, y, 'ro-', markersize=8, lw=2)
    plt.grid(True)
    plt.xlabel('Num Clusters')
    plt.ylabel('Inertia')
    plt.show()


def select_clusters(dataset, init_cluster='k-means++', tolerance=0.0001,loops=10,max_iterations=10,
                    jobs=16):

    inertia_clusters = list()

    for i in range(1, loops + 1, 1):
        # Object KMeans
        kmeans = KMeans(n_clusters=i, max_iter=max_iterations,
                        init=init_cluster, tol=tolerance, n_jobs=jobs)

        # Calculate Kmeans
        kmeans.fit(dataset)

        # Obtain inertia
        inertia_clusters.append([i, kmeans.inertia_])

    plot_results(inertia_clusters)

# %%
select_clusters(dataset = buildings,loops = 20)

# %% [markdown]
# Based on the graph three
